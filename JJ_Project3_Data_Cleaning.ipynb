# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step 1: Cleaning and Organizing Data

# %%
#project 3 data
df = pd.read_csv('new_train_EGN5442.csv')
print(df.head())
# Out:
#    Unnamed: 0  y      x2      x3  x5  x9  x10  x11  x12  x13  ... x23   x24  \
# 0           0  1  #54359  Female  50   5    5    5    4    3  ...  21  12.0
# 1           1  1  #84649  Female  44   1    1    1    1    3  ...   0   0.0
# 2           2  0  #59015  Female  72   3    1    5    5    3  ...   0   8.0
# 3           3  0  #99990  Female  38   1    3    1    3    5  ...   0   0.0
# 4           4  1  #83569    Male  37   5    5    5    5    2  ...   0   0.0
#
#    x25  x26  x28       x29  x30       x31  x4  x6
# 0  D_C   Bt    1   (192&&)  NaN  2.380952   4  50
# 1  L_C   Bt    1  (1034&&)  NaN       inf   4  44
# 2  L_C   Bt    3  (1452&&)  NaN       inf   4  72
# 3  L_C   PT    3   (916&&)  NaN       inf   4  38
# 4  L_C   Bt    1   (390&&)  NaN       inf   4  37
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104722 entries, 0 to 104721
# Data columns (total 29 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  104722 non-null  int64
#  1   y           104722 non-null  int64
#  2   x2          104722 non-null  object
#  3   x3          104722 non-null  object
#  4   x5          104722 non-null  int64
#  5   x9          104722 non-null  int64
#  6   x10         104722 non-null  int64
#  7   x11         104722 non-null  int64
#  8   x12         104722 non-null  int64
#  9   x13         104722 non-null  int64
#  10  x14         104722 non-null  object
#  11  x15         104722 non-null  int64
#  12  x16         104722 non-null  int64
#  13  x17         104722 non-null  int64
#  14  x18         104722 non-null  int64
#  15  x19         104722 non-null  int64
#  16  x20         104722 non-null  int64
#  17  x21         104722 non-null  int64
#  18  x22         104722 non-null  int64
#  19  x23         104722 non-null  int64
#  20  x24         104410 non-null  float64
#  21  x25         104722 non-null  object
#  22  x26         104722 non-null  object
#  23  x28         104722 non-null  int64
#  24  x29         104722 non-null  object
#  25  x30         0 non-null       float64
#  26  x31         104722 non-null  float64
#  27  x4          104722 non-null  int64
#  28  x6          104722 non-null  int64
# dtypes: float64(3), int64(20), object(6)
# memory usage: 23.2+ MB

# %%
df.describe()
# Out:
# C:\Users\jialj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# C:\Users\jialj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:4671: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#           Unnamed: 0              y             x5             x9  \
# count  104722.000000  104722.000000  104722.000000  104722.000000
# mean    52360.500000       0.431380      39.189273       2.728892
# std     30230.781782       0.495271      15.208026       1.326905
# min         0.000000       0.000000       7.000000       0.000000
# 25%     26180.250000       0.000000      27.000000       2.000000
# 50%     52360.500000       0.000000      40.000000       3.000000
# 75%     78540.750000       1.000000      51.000000       4.000000
# max    104721.000000       1.000000      85.000000       5.000000
#
#                  x10            x11            x12            x13  \
# count  104722.000000  104722.000000  104722.000000  104722.000000
# mean        3.062986       2.755591       2.977187       3.201419
# std         1.525021       1.398492       1.277116       1.329776
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       2.000000       2.000000       2.000000
# 50%         3.000000       3.000000       3.000000       3.000000
# 75%         4.000000       4.000000       4.000000       4.000000
# max         5.000000       5.000000       5.000000       5.000000
#
#                  x15            x16  ...            x20            x21  \
# count  104722.000000  104722.000000  ...  104722.000000  104722.000000
# mean        3.436317       3.356458  ...       3.303909       3.641088
# std         1.320007       1.333305  ...       1.265508       1.175039
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         2.000000       2.000000  ...       3.000000       3.000000
# 50%         4.000000       4.000000  ...       3.000000       4.000000
# 75%         5.000000       4.000000  ...       4.000000       5.000000
# max         5.000000       5.000000  ...       5.000000       5.000000
#
#                  x22            x23            x24            x28  x30  \
# count  104722.000000  104722.000000  104410.000000  104722.000000  0.0
# mean        3.285155      14.818405      15.188909       1.976089  NaN
# std         1.312749      38.305687      38.785838       0.962887  NaN
# min         0.000000       0.000000       0.000000       1.000000  NaN
# 25%         2.000000       0.000000       0.000000       1.000000  NaN
# 50%         3.000000       0.000000       0.000000       2.000000  NaN
# 75%         4.000000      12.000000      13.000000       3.000000  NaN
# max         5.000000    1592.000000    1584.000000       3.000000  NaN
#
#                 x31        x4             x6
# count  1.047220e+05  104722.0  104722.000000
# mean            inf       4.0      39.189273
# std             NaN       0.0      15.208026
# min    9.668508e-03       4.0       7.000000
# 25%    3.000000e+00       4.0      27.000000
# 50%             NaN       4.0      40.000000
# 75%             NaN       4.0      51.000000
# max             inf       4.0      85.000000
#
# [8 rows x 23 columns]

# %%
df.nunique()
# Out:
# Unnamed: 0    104722
# y                  2
# x2            103904
# x3                 2
# x5                75
# x9                 6
# x10                6
# x11                6
# x12                6
# x13                6
# x14                6
# x15                6
# x16                6
# x17                6
# x18                6
# x19                5
# x20                6
# x21                6
# x22                6
# x23              446
# x24              455
# x25                2
# x26                2
# x28                3
# x29             3802
# x30                0
# x31             5541
# x4                 1
# x6                75
# dtype: int64

# %%
#find if string or dateime columns?
#use apply() with user-defined functions or lambda expressions
df.dtypes.apply(lambda x: x == 'object')
df.dtypes.apply(lambda x: 'datetime' in str(x))
# Out:
# Unnamed: 0    False
# y             False
# x2            False
# x3            False
# x5            False
# x9            False
# x10           False
# x11           False
# x12           False
# x13           False
# x14           False
# x15           False
# x16           False
# x17           False
# x18           False
# x19           False
# x20           False
# x21           False
# x22           False
# x23           False
# x24           False
# x25           False
# x26           False
# x28           False
# x29           False
# x30           False
# x31           False
# x4            False
# x6            False
# dtype: bool

# %% [markdown]
# There are no object (string) columns or any datetime columns.

# %%
#Missing data
print(df.isna().sum())
# Out:
# Unnamed: 0         0
# y                  0
# x2                 0
# x3                 0
# x5                 0
# x9                 0
# x10                0
# x11                0
# x12                0
# x13                0
# x14                0
# x15                0
# x16                0
# x17                0
# x18                0
# x19                0
# x20                0
# x21                0
# x22                0
# x23                0
# x24              312
# x25                0
# x26                0
# x28                0
# x29                0
# x30           104722
# x31                0
# x4                 0
# x6                 0
# dtype: int64

# %%
#find duplicated rows
print(df.duplicated().sum())

#deal with duplicated data
df.drop_duplicates(inplace=True)
# Out:
# 0

# %%
#find highly correlated columns/features among numeric columns
df.select_dtypes(include=['number']).corr()
corr_matrix = df.select_dtypes(include=['number']).corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
#can drop highly correlated column

df.drop(columns=['x24'], inplace=True)
print("Shape after dropping x24:", df.shape)
# Out:
# Shape after dropping x24: (104722, 28)

# %%
#exploring categorical data columns - get_dummies() method
cat_cols = df.select_dtypes(include='object').columns
df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

print(df.shape)
# Out:
# (104722, 107734)

# %%
#explore continous data columns - bin data into some bins or quantiles
df['x5_binned'] = pd.cut(df['x5'], bins=5, labels=False, include_lowest=True)
print("Value counts for 'x5_binned':")
print(df['x5_binned'].value_counts().sort_index())

display(df.head())
# Out:
# Value counts for 'x5_binned':
# x5_binned
# 0    16009
# 1    33226
# 2    34813
# 3    19301
# 4     1373
# Name: count, dtype: int64
#    Unnamed: 0  y  x5  x9  x10  x11  x12  x13  x15  x16  ...  x29_(991&&)  \
# 0           0  1  50   5    5    5    4    3    3    3  ...        False
# 1           1  1  44   1    1    1    1    3    1    4  ...        False
# 2           2  0  72   3    1    5    5    3    2    3  ...        False
# 3           3  0  38   1    3    1    3    5    5    5  ...        False
# 4           4  1  37   5    5    5    5    2    5    4  ...        False
#
#    x29_(992&&)  x29_(993&&)  x29_(994&&)  x29_(995&&)  x29_(996&&)  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    x29_(997&&)  x29_(998&&)  x29_(999&&)  x5_binned
# 0        False        False        False          2
# 1        False        False        False          2
# 2        False        False        False          4
# 3        False        False        False          1
# 4        False        False        False          1
#
# [5 rows x 107735 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

num_cols = df.select_dtypes(include='number').columns

# Exclude columns with infinite values before plotting histograms
finite_num_cols = [col for col in num_cols if not np.isinf(df[col]).any()]

df[finite_num_cols].hist(figsize=(12, 10), bins=20)
plt.suptitle("Histograms of Numeric Features (Excluding Columns with Infinite Values)", y=1.02)
plt.tight_layout(rect=[0, 0.03, 1, 0.98]) # Adjust layout to prevent title overlap
plt.show()

# %%
obj_cols = df.select_dtypes(include='object').columns
print("Object columns:", obj_cols.tolist())

# missing data
na_counts = df.isna().sum().sort_values(ascending=False)
print(na_counts.head(20))

# visualize missing (only show columns that actually have NAs)
na_counts_nonzero = na_counts[na_counts > 0]
plt.figure()
na_counts_nonzero.plot(kind='bar')
plt.ylabel("Number of missing values")
plt.title("Missing values per feature")
plt.tight_layout()
plt.show()
# Out:
# Object columns: []
# x30            104722
# x29_(969&&)         0
# x2_#100003          0
# x5_binned           0
# Unnamed: 0          0
# y                   0
# x5                  0
# x9                  0
# x10                 0
# x11                 0
# x12                 0
# x13                 0
# x15                 0
# x16                 0
# x17                 0
# x18                 0
# x19                 0
# x20                 0
# x21                 0
# x22                 0
# dtype: int64

# %%
df['x30'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: x30, dtype: float64

# %%
df.drop(columns=['x30'], inplace=True)
df.isna().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0     0
# y              0
# x5             0
# x9             0
# x10            0
#               ..
# x29_(996&&)    0
# x29_(997&&)    0
# x29_(998&&)    0
# x29_(999&&)    0
# x5_binned      0
# Length: 107734, dtype: int64

# %%
#export data to csv
df.to_csv('cleaned_new_train_EGN5442.csv', index=False)
print("DataFrame exported to 'cleaned_new_train_EGN5442.csv'")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9072\4193691281.py in ?()
#       1 #export data to csv
# ----> 2 df.to_csv('cleaned_new_train_EGN5442.csv', index=False)
#       3 print("DataFrame exported to 'cleaned_new_train_EGN5442.csv'")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py in ?(*args, **kwargs)
#     329                     msg.format(arguments=_format_argument_list(allow_args)),
#     330                     FutureWarning,
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3985             float_format=float_format,
#    3986             decimal=decimal,
#    3987         )
#    3988
# -> 3989         return DataFrameRenderer(formatter).to_csv(
#    3990             path_or_buf,
#    3991             lineterminator=lineterminator,
#    3992             sep=sep,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\format.py in ?(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1010             escapechar=escapechar,
#    1011             storage_options=storage_options,
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#    1017             assert isinstance(path_or_buf, StringIO)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py in ?(self)
#     266                 escapechar=self.escapechar,
#     267                 quotechar=self.quotechar,
#     268             )
#     269
# --> 270             self._save()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py in ?(self)
#     272     def _save(self) -> None:
#     273         if self._need_to_save_header:
#     274             self._save_header()
# --> 275         self._save_body()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py in ?(self)
#     309             start_i = i * self.chunksize
#     310             end_i = min(start_i + self.chunksize, nrows)
#     311             if start_i >= end_i:
#     312                 break
# --> 313             self._save_chunk(start_i, end_i)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py in ?(self, start_i, end_i)
#     317         slicer = slice(start_i, end_i)
#     318         df = self.obj.iloc[slicer]
#     319
#     320         res = df._get_values_for_csv(**self._number_format)
# --> 321         data = list(res._iter_column_arrays())
#     322
#     323         ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
#     324         libwriters.write_csv_rows(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self)
#    4046         if isinstance(self._mgr, ArrayManager):
#    4047             yield from self._mgr.arrays
#    4048         else:
#    4049             for i in range(len(self.columns)):
# -> 4050                 yield self._get_column_array(i)
#
# KeyboardInterrupt:
